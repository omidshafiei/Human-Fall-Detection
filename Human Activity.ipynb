# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy import stats
from sklearn import svm, datasets , metrics

# %%
data = np.loadtxt("BBH.txt")
Tdata = np.loadtxt("TBBH.txt")


XTrain = data[:,0:520]
yTrain = data[:,520]
print(XTrain.shape)


XTest = Tdata[:,0:520]
yTest = Tdata[:,520]
# Out:
# (105, 520)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(XTrain, yTrain)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(XTrain.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(XTrain.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(XTrain.shape[1]), indices)
plt.xlim([-1, XTrain.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 49 (0.016356)
# 2. feature 4 (0.015060)
# 3. feature 55 (0.014935)
# 4. feature 498 (0.013306)
# 5. feature 57 (0.012380)
# 6. feature 5 (0.012034)
# 7. feature 18 (0.011987)
# 8. feature 30 (0.011784)
# 9. feature 33 (0.011573)
# 10. feature 94 (0.011527)
# 11. feature 519 (0.011492)
# 12. feature 461 (0.011483)
# 13. feature 35 (0.011244)
# 14. feature 19 (0.011233)
# 15. feature 15 (0.010779)
# 16. feature 464 (0.010676)
# 17. feature 92 (0.010434)
# 18. feature 37 (0.010380)
# 19. feature 53 (0.010378)
# 20. feature 96 (0.010124)
# 21. feature 16 (0.010121)
# 22. feature 31 (0.009962)
# 23. feature 51 (0.009756)
# 24. feature 496 (0.009599)
# 25. feature 487 (0.009598)
# 26. feature 508 (0.009557)
# 27. feature 45 (0.009238)
# 28. feature 509 (0.009022)
# 29. feature 58 (0.008613)
# 30. feature 74 (0.008230)
# 31. feature 0 (0.008159)
# 32. feature 56 (0.008046)
# 33. feature 26 (0.007975)
# 34. feature 99 (0.007574)
# 35. feature 32 (0.007552)
# 36. feature 510 (0.007538)
# 37. feature 412 (0.007429)
# 38. feature 28 (0.007406)
# 39. feature 97 (0.007368)
# 40. feature 60 (0.007327)
# 41. feature 83 (0.007264)
# 42. feature 153 (0.007234)
# 43. feature 43 (0.007173)
# 44. feature 41 (0.006844)
# 45. feature 63 (0.006830)
# 46. feature 14 (0.006789)
# 47. feature 466 (0.006750)
# 48. feature 422 (0.006721)
# 49. feature 62 (0.006653)
# 50. feature 1 (0.006592)
# 51. feature 73 (0.006498)
# 52. feature 516 (0.006366)
# 53. feature 406 (0.006326)
# 54. feature 477 (0.006312)
# 55. feature 125 (0.006243)
# 56. feature 186 (0.006204)
# 57. feature 72 (0.006030)
# 58. feature 460 (0.006017)
# 59. feature 2 (0.005972)
# 60. feature 93 (0.005921)
# 61. feature 81 (0.005857)
# 62. feature 38 (0.005812)
# 63. feature 514 (0.005724)
# 64. feature 59 (0.005671)
# 65. feature 513 (0.005593)
# 66. feature 24 (0.005590)
# 67. feature 20 (0.005367)
# 68. feature 184 (0.005334)
# 69. feature 155 (0.005313)
# 70. feature 105 (0.005294)
# 71. feature 448 (0.005236)
# 72. feature 198 (0.005226)
# 73. feature 36 (0.005211)
# 74. feature 126 (0.005206)
# 75. feature 44 (0.005150)
# 446. feature 262 (0.000000)
# 447. feature 282 (0.000000)
# 448. feature 278 (0.000000)
# 449. feature 276 (0.000000)
# 450. feature 274 (0.000000)
# 451. feature 273 (0.000000)
# 452. feature 272 (0.000000)
# 453. feature 269 (0.000000)
# 454. feature 268 (0.000000)
# 455. feature 267 (0.000000)
# 456. feature 265 (0.000000)
# 457. feature 261 (0.000000)
# 458. feature 241 (0.000000)
# 459. feature 518 (0.000000)
# 460. feature 257 (0.000000)
# 461. feature 256 (0.000000)
# 462. feature 253 (0.000000)
# 463. feature 249 (0.000000)
# 464. feature 247 (0.000000)
# 465. feature 246 (0.000000)
# 466. feature 245 (0.000000)
# 467. feature 243 (0.000000)
# 468. feature 242 (0.000000)
# 469. feature 305 (0.000000)
# 470. feature 192 (0.000000)
# 471. feature 306 (0.000000)
# 472. feature 339 (0.000000)
# 473. feature 141 (0.000000)
# 474. feature 330 (0.000000)
# 475. feature 331 (0.000000)
# 476. feature 332 (0.000000)
# 477. feature 135 (0.000000)
# 478. feature 334 (0.000000)
# 479. feature 132 (0.000000)
# 480. feature 336 (0.000000)
# 481. feature 337 (0.000000)
# 482. feature 338 (0.000000)
# 483. feature 340 (0.000000)
# 484. feature 307 (0.000000)
# 485. feature 341 (0.000000)
# 486. feature 342 (0.000000)
# 487. feature 343 (0.000000)
# 488. feature 118 (0.000000)
# 489. feature 117 (0.000000)
# 490. feature 116 (0.000000)
# 491. feature 345 (0.000000)
# 492. feature 110 (0.000000)
# 493. feature 109 (0.000000)
# 494. feature 347 (0.000000)
# 495. feature 285 (0.000000)
# 496. feature 143 (0.000000)
# 497. feature 144 (0.000000)
# 498. feature 146 (0.000000)
# 499. feature 188 (0.000000)
# 500. feature 309 (0.000000)
# 501. feature 311 (0.000000)
# 502. feature 182 (0.000000)
# 503. feature 181 (0.000000)
# 504. feature 312 (0.000000)
# 505. feature 179 (0.000000)
# 506. feature 177 (0.000000)
# 507. feature 176 (0.000000)
# 508. feature 172 (0.000000)
# 509. feature 314 (0.000000)
# 510. feature 315 (0.000000)
# 511. feature 169 (0.000000)
# 512. feature 317 (0.000000)
# 513. feature 318 (0.000000)
# 514. feature 320 (0.000000)
# 515. feature 321 (0.000000)
# 516. feature 322 (0.000000)
# 517. feature 324 (0.000000)
# 518. feature 328 (0.000000)
# 519. feature 151 (0.000000)
# 520. feature 244 (0.000000)

# %%
# from sklearn.svm import LinearSVC

# from sklearn.feature_selection import SelectFromModel


# XTrain.shape
# print(XTrain.shape)

# lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(XTrain, yTrain)
# model = SelectFromModel(lsvc, prefit=True)
# X_new = model.transform(XTrain)
# X_new.shape

# print(X_new.shape)

# %%
# h = .02  # step size in the mesh


range_C = {0.00001,0.0001, 0.001,0.01,0.1,1}

for C in range_C:
    
    svc = svm.SVC(kernel='linear', C=C).fit(XTrain, yTrain)




    # Now predict the value of the digit on the test data:
    expected = yTest
    predicted = svc.predict(XTest)

    print("Classification report for classifier %s:\n%s\n"
          % (svc, metrics.classification_report(expected, predicted)))
    print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
# Out:
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=1e-05, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.94      1.00      0.97       192
#         3.0       1.00      0.95      0.98       286
#
# avg / total       0.98      0.98      0.98       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0  13 273]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.97      1.00      0.99       192
#         3.0       1.00      0.98      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   5 281]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]

# %%
# h = .02  # step size in the mesh


range_Q = {2,3,4,5}
range_C = {0.0001, 0.001,0.01,0.1,1}

for Q in range_Q:
    for C in range_C:

        poly_svc = svm.SVC(kernel='poly', degree=Q, C=C).fit(XTrain, yTrain)




        # Now predict the value of the digit on the test data:
        expected = yTest
        predicted = poly_svc.predict(XTest)

        print("Classification report for classifier %s:\n%s\n"
              % (poly_svc, metrics.classification_report(expected, predicted)))
        print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
# Out:
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.98      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   7 279]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=4, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.98       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   9 277]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=4, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.98       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   9 277]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=4, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.98       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   9 277]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=4, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.98       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   9 277]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=4, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.98       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   9 277]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=5, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       1.00      1.00      1.00       192
#         2.0       0.96      1.00      0.98       192
#         3.0       1.00      0.97      0.99       286
#
# avg / total       0.99      0.99      0.99       670
#
#
# Confusion matrix:
# [[192   0   0]
#  [  0 192   0]
#  [  0   8 278]]

# %%
h = .02  # step size in the mesh

range_gamma = {0.01,0.05,0.1,0.2,0.5}
range_Q = {2,3,4,5}
range_C = {0.0001, 0.001,0.01,0.1,1}

for gamma in range_gamma:
    for Q in range_Q:
        for C in range_C:
            svc = svm.SVC(kernel='rbf', gamma=gamma, C=C).fit(XTrain, yTrain)




            # Now predict the value of the digit on the test data:
            expected = yTest
            predicted = svc.predict(XTest)

            print("Classification report for classifier %s:\n%s\n"
                  % (svc, metrics.classification_report(expected, predicted)))
            print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# Classification report for classifier SVC(C=0.0001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.05, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#         1.0       0.00      0.00      0.00       192
#         2.0       0.00      0.00      0.00       192
#         3.0       0.43      1.00      0.60       286
#
# avg / total       0.18      0.43      0.26       670
#
#
# Confusion matrix:
# [[  0   0 192]
#  [  0   0 192]
#  [  0   0 286]]
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
h = .02  # step size in the mesh

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
svc = svm.SVC(kernel='linear', C=C).fit(XTrain, yTrain)
#svc = svm.SVC(kernel='rbf', gamma=0.05, C=C).fit(XTrain, yTrain)
# rbf_svc = svm.SVC(kernel='rbf', gamma=0.7, C=C).fit(XTrain, yTrain)
# poly_svc = svm.SVC(kernel='poly', degree=3, C=C).fit(XTrain, yTrain)
# lin_svc = svm.LinearSVC(C=C).fit(XTrain, yTrain)



# Now predict the value of the digit on the test data:
expected = yTest
predicted = svc.predict(XTest)

print("Classification report for classifier %s:\n%s\n"
      % (svc, metrics.classification_report(expected, predicted)))
print("Confusion matrix:\n%s" % metrics.confusion_matrix(expected, predicted))
